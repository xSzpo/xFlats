# %%
import boto3
import bson
from bson.json_util import dumps, loads
import json
import os
from PIL import Image
import PIL
from io import BytesIO

# %%
# import helper 
import sys
sys.path.append("/Users/xszpo/Google Drive/DataScience/Projects/201907_xFlat_AWS_Scrapy")
import helpers

# run scrapy settings
# %run /Users/xszpo/Google\ Drive/DataScience/Projects/201907_xFlat_AWS_Scrapy/scraper/settings.py

# %%
LOCAL_DATA_PATH
# Out:
# '/Users/xszpo/Google Drive/DataScience/DATA/01_otodo_scrapy'

# %%
file_list = [i for i in os.listdir(LOCAL_DATA_PATH) if i.endswith(".bson")]

# %%
len(file_list)
# Out:
# 15821

# %%
file_1 = helpers.scraper.read_bson_local(LOCAL_DATA_PATH, file_list[-9])
helpers.scraper.open_img_from_str(file_1['img_gallery_strimg'][0])
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=400x300 at 0x10B562A20>

# %%
helpers.scraper.open_img_from_str(file_1['img_gallery_strimg'][1])
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=399x300 at 0x10B795D30>

# %%
helpers.scraper.open_img_from_str(file_1['img_gallery_strimg'][2])
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=399x300 at 0x104B77E80>

# %%
helpers.scraper.dict_except(file_1,['img_gallery_strimg','gallery'])
# Out:
# {'flat_size': '44 m²',
#  'img_cover_title': 'Mieszkanie na sprzedaż o powierzchni 44 m² - Warszawa, Białołęka - zdjęcie 1',
#  'issued_by': '\n                                                                                                        JW Construction                                                                                        ',
#  'location': 'Warszawa, Białołęka',
#  'offer_id': '3VfHy',
#  'offer_title': 'Idealne na START lub Najem 2 pok. busy do Metra!',
#  'price': '326 000 zł',
#  'price_per_square': '7 409 zł/m²',
#  'rooms': '2',
#  'tracking_id': ' 58212392',
#  'type': 'listing_no_promo',
#  'url': 'https://www.otodom.pl/oferta/idealne-na-start-lub-najem-2-pok-busy-do-metra-ID3VfHy.html#de0fbfbe43',
#  'url_offer_list': 'https://www.otodom.pl/sprzedaz/mieszkanie/warszawa/?page=576',
#  'producer_name': 'otodom',
#  'main_url': 'otodom.pl',
#  'offer_type': 'Oferta biura nieruchomości',
#  'name': 'Idealne na START lub Najem 2 pok. busy do Metra!',
#  'price_m2': '7 409 zł/m²',
#  'market': 'pierwotny',
#  'building_type': 'blok',
#  'floor': None,
#  'number_of_floors': None,
#  'building_material': 'cegła',
#  'widows_type': 'plastikowe',
#  'heating_type': 'miejskie',
#  'year_of_building': '2018',
#  'finishing_stage': 'do wykończenia',
#  'rent_price': '7 zł',
#  'property_form': None,
#  'available_from': None,
#  'description': 'Sprzedam tanio\xa0na\xa0Białołęce\xa0bezpośrednio dlatego cena jest tak niska!\n\r\n\nW razie pytań proszę dzwonić na nr \n506 017 403\n.\n\r\n\nIdealne dla rodziny\n\r\n\nPiękne ustawne 2 pokojowe mieszkanie\n \nz dużym balkonem\n\r\n\nNa przeciwko powstaje Publiczna Szkoła Podstawowa z dużym zapleczem sportowym.\n\r\n\nMieszkanie nowe, nieużywane więc nie płacisz podatku PCC i żadnych prowizji co wiąże się z dużymi oszczędnościami dla Twojego portfela.\n\r\n\nNowe osiedle, proekologiczne rozwiązania dzięki czemu czynsz jest na niskim poziomie.\n\r\n\nDuże panoramiczne\xa0okna więc w mieszkaniu jest dużo dziennego światła co wpływa na dobre samopoczucie.\n\r\n\nOsiedle znajduje się tuz przy\xa0przystanku ZTM więc jest dobrze skomunikowane z metrem dzięki czemu nie tracisz dużo czasu na dojazdy.\n\r\n\nWysoki standard wykończenia, materiały najwyższej jakości i 5-letnia gwarancja od momentu odbioru dlatego nie musisz martwić się o jakiekolwiek naprawy w trakcie użytkowania mieszkania.\n\r\n\nMieszkasz w sąsiedztwie parków, lasów, łąk. Większość terenów zielonych została zrewitalizowana (do dyspozycji mieszkańców są nowe place zabaw, ścieżki rowerowe, baseny, stawy).\n\r\n\nZapraszam do kontaktu. Przedstawię szczegółowo ofertę. Posiadamy również inne układy mieszkań w tej inwestycji. Zachęcam do wspólnej wizyty na terenie Osiedla \n506 017 403',
#  'additional_info': 'telewizja kablowa|internet|telefon|system alarmowy|drzwi / okna antywłamaniowe|teren zamknięty|domofon / wideofon|monitoring / ochrona|balkon|garaż/miejsce parkingowe|pom. użytkowe',
#  'agency_tracking_id': '',
#  'add_rel_date': ' 6 months ago',
#  'update_rel_date': ' 22 days ago',
#  'download_date': 1567589450,
#  'geo_coordinates': {'@type': 'GeoCoordinates',
#   'latitude': '52.32899',
#   'longitude': '21.00768'},
#  'geo_address_text': {'house_number': '23',
#   'road': 'Borecka',
#   'neighbourhood': 'Białołęka Dworska',
#   'suburb': 'Białołęka',
#   'city': 'Warszawa',
#   'county': 'Warszawa',
#   'state': 'mazowieckie',
#   'postcode': '03-034',
#   'country': 'RP',
#   'country_code': 'pl'},
#  'geo_address_coordin': {'@place_id': '109714934',
#   '@osm_type': 'way',
#   '@osm_id': '148063175',
#   '@lat': '52.32864875',
#   '@lon': '21.00802425',
#   '@boundingbox': '52.3286073,52.3286902,21.0079772,21.0080713',
#   '#text': '23, Borecka, Białołęka Dworska, Białołęka, Warszawa, mazowieckie, 03-034, RP'}}
