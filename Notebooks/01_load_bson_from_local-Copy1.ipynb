# %%
import boto3
import bson
from bson.json_util import dumps, loads
import json
import os
from PIL import Image
import PIL
from io import BytesIO

# %%
import sys
sys.path.append("/Users/xszpo/Google Drive/DataScience/Projects/201907_xFlat_AWS_Scrapy")

# %%
# %run /Users/xszpo/Google\ Drive/DataScience/Projects/201907_xFlat_AWS_Scrapy/scraper/settings.py

# %%
import helpers

# %%
file_list = helpers.scraper.list_bucket(BUCKET_NAME)

# %%
file_1=helpers.scraper.load_bson_s3(file_list[-1], BUCKET_NAME)

# %%
helpers.scraper.open_img_from_str(file_1['img_gallery_strimg'][0])
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=399x300 at 0x11403EF60>

# %%
helpers.scraper.open_img_from_str(file_1['img_gallery_strimg'][1])
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=399x300 at 0x1140E3E48>

# %%
helpers.scraper.open_img_from_str(file_1['img_gallery_strimg'][2])
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=399x300 at 0x1140F6128>
